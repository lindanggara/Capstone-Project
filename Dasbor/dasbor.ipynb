# %%
from google.colab import drive
import shutil

# Mount Drive
drive.mount('/content/drive')

# Salin kembali ke sistem lokal Colab agar skrip berjalan lancar
shutil.copy('/content/drive/MyDrive/Dasbor/wellguard.csv', './wellguard.csv')
shutil.copy('/content/drive/MyDrive/Dasbor/wellguard_model.pt', './wellguard_model.pt')
shutil.copy('/content/drive/MyDrive/Dasbor/app.py', './app.py')

print("🚀 File berhasil ditarik dari Drive! Siap digunakan.")
# Out:
# Mounted at /content/drive
# 🚀 File berhasil ditarik dari Drive! Siap digunakan.

# %%
# !pip install pyngrok
# !pip install streamlit plotly xgboost shap joblib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 57.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 102.2 MB/s eta 0:00:00
# ...

# %%
# !ngrok config add-authtoken 3BWY8wB0LdxTkEsVnyPDEoa5dr6_5ZhMsaRy3HGiyX1FvKMRP
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
from pyngrok import ngrok
import time

# 1. Matikan tunnel ngrok yang mungkin masih aktif sebelumnya (agar tidak error)
ngrok.kill()

# 2. Jalankan Streamlit di background (port default 8501)
get_ipython().system_raw('streamlit run app.py &')

# Beri waktu 3 detik agar server Streamlit menyala sepenuhnya
time.sleep(3)

# 3. Buka tunnel ke port 8501
public_url = ngrok.connect(8501)

print("✅ Server Aktif!")
print(f"🚀 Buka Dashboard WellGuard di sini: {public_url}")
# Out:
# ✅ Server Aktif!
# 🚀 Buka Dashboard WellGuard di sini: NgrokTunnel: "https://unfoolishly-horsiest-gudrun.ngrok-free.dev" -> "http://localhost:8501"

# %%
# !mkdir -p .streamlit

# %%
# !curl ipv4.icanhazip.com
# Out:
# 34.106.106.142

# %%
from pyngrok import ngrok

# Terminate all active ngrok tunnels
ngrok.kill()

# Find and kill the streamlit process
# !pkill streamlit

print("🛑 Ngrok and Streamlit have been stopped.")
# Out:
# 🛑 Ngrok and Streamlit have been stopped.
